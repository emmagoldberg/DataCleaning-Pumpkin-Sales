# %% [markdown]
# # Data Cleaning Studio
#
# You are part of a team working for an agricultural nonprofit based in California. Your nonprofit focuses on helping farmers in the state grow profitable crops in environmentally-friendly ways in an effort to reduce the impact of climate change on the state and provide enough food for the state's 39.5 million residents. With Halloween on the horizon, you and your team are looking to analyze past pumpkin crops to try and answer several questions:
# 1. Are pumpkins sold at terminal markets in California (San Francisco and Los Angeles) grown in California?
# 1. Is the harvest season for pumpkins grown in California consistent year-to-year?
# 1. Are pumpkin farmers growing specific varieties of pumpkins for specific reasons?
#
# The answers to these questions will help your nonprofit decide if they should promote specific varieties or growing practices to the farmers they serve in time for seeds to be planted next year. Your team has already performed some exploratory analysis on the San Francisco terminal market report of pumpkin sales from 9/2016-9/2017. Now it is time to clean the data!
#
# Before diving in to cleaning the data, here is a quick guide to the different columns in the USDA report and what they mean:
# - Commodity Name: This CSV structure is used for lots of USDA reports. In this case, the commodity is pumpkins
# - City Name: City where the pumpkin was sold. The city is a terminal market location within the United States.
# - Type: This refers to the type of farming used in growing the pumpkins
# - Package: The way the pumpkins were packed for sale
# - Variety: Specific type of pumpkin, i.e. pie pumpkin or a Howden pumpkin
# - Sub Variety: Addition classifications about the pumpkins, i.e. is it a flat pumpkin?
# - Grade: In the US, usually only canned pumpkin is graded
# - Date: Date of sale (rounded up to the nearest Saturday)
# - Low Price: This price is in reference to sale price
# - High Price: This price is in reference to sale price
# - Mostly Low: This column is not measured for pumpkins
# - Mostly High: This column is not measured for pumpkins
# - Origin: Which state the pumpkins were grown in
# - Origin District: Additional information about pumpkins' origin location
# - Item Size: Abbreviations denoting size, i.e. jbo = jumbo, lrg = large
# - Color: Color of pumpkins
# - Environment: Additional information about pumpkins' growing environment
# - Unit of Sale: The unit the customer bought at market, i.e. if they bought pumpkins by the pound, the data should say "PER LB" or  if they bought pumpkins by the bin, it would say "PER BIN"
# - Quality: Additional notes about pumpkin quality as necessary
# - Condition: Additional notes about pumpkin condition as necessary
# - Appearance: Additional notes about pumpkin appearance as necessary
# - Storage: Additional notes about pumpkin storage as necessary
# - Crop: Additional notes about pumpkin crop as necessary
# - Repack: Whether the pumpkin has been repackaged before sale
# - Trans Mode: Mode of transportation used to get pumpkins to terminal market

# %%
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("C:/Users/emmag/Desktop/Women+/DataCleaning-Pumpkin-Sales/san-fransisco_9-24-2016_9-30-2017.csv")

# %%
df.head()
df.tail()
# Out:
#     Commodity Name      City Name Type        Package    Variety Sub Variety  \
# 161       PUMPKINS  SAN FRANCISCO  NaN  40 lb cartons  MINIATURE  ROUND TYPE
# 162       PUMPKINS  SAN FRANCISCO  NaN  40 lb cartons  MINIATURE  ROUND TYPE
# 163       PUMPKINS  SAN FRANCISCO  NaN  40 lb cartons  MINIATURE  ROUND TYPE
# 164       PUMPKINS  SAN FRANCISCO  NaN  40 lb cartons  MINIATURE  ROUND TYPE
# 165       PUMPKINS  SAN FRANCISCO  NaN  40 lb cartons  MINIATURE  ROUND TYPE
#
#      Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 161    NaN  10/08/2016       30.0        35.0  ...    NaN          NaN
# 162    NaN  10/15/2016       30.0        35.0  ...    NaN          NaN
# 163    NaN  10/22/2016       30.0        35.0  ...    NaN          NaN
# 164    NaN  10/29/2016       30.0        30.0  ...    NaN          NaN
# 165    NaN  11/05/2016       30.0        30.0  ...    NaN          NaN
#
#     Unit of Sale  Quality Condition Appearance  Storage  Crop  Repack  \
# 161          NaN      NaN       NaN        NaN      NaN   NaN       N
# 162          NaN      NaN       NaN        NaN      NaN   NaN       N
# 163          NaN      NaN       NaN        NaN      NaN   NaN       N
# 164          NaN      NaN       NaN        NaN      NaN   NaN       N
# 165          NaN      NaN       NaN        NaN      NaN   NaN       N
#
#      Trans Mode
# 161         NaN
# 162         NaN
# 163         NaN
# 164         NaN
# 165         NaN
#
# [5 rows x 25 columns]

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 78%
# Package - 0%
# Variety - 0%
# Sub Variety - 61%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 75%
# Color - 72%
# Environment - 100%
# Unit of Sale - 100%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
# Checking the overall percentage of missing data from the data set

total_cells = np.product(df.shape)

missing_cells = pd.isnull(df).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")
# Out:
# 51.0 % Missing cells from the data

# %% [markdown]
# ### Question 1:
#
# Look at the percentages of missing data per coluum.  There are quite a few columns with less than 100% of the data.  What do you want to do with each column?   Consider the following options for each and write down your thoughts in a box below this one.
# 1. Drop the Observation
# 1. Drop the Feature
# 1. Impute the Missing Values
# 1. Replace the Missing Values

# %%
# Answer Question 1 here:

#For Origin District, Environment, Unit of Sale, Quality, Condition, Appearance, Storage, Crop, Trans Mode, and Grade we will drop the feature
#For Type, Sub Variety, Color, and Item Size we will fill missing values with "Unknown".

# %%
# Repack Column
df["Repack"] = df["Repack"].replace({"N":False})
#Check status with a quick head check
df.head(3)
# Out:
#   Commodity Name      City Name Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/24/2016      155.0       155.0  ...    NaN          NaN
# 1    NaN  10/01/2016      155.0       155.0  ...    NaN          NaN
# 2    NaN  10/01/2016      155.0       155.0  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition Appearance  Storage  Crop  Repack  \
# 0          NaN      NaN       NaN        NaN      NaN   NaN   False
# 1          NaN      NaN       NaN        NaN      NaN   NaN   False
# 2          NaN      NaN       NaN        NaN      NaN   NaN   False
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
#
# [3 rows x 25 columns]

# %% [markdown]
# # Question 2:
#
# Look at the "Type" column.  This column contains two values, "Organic" and "NaN".
# When it comes to food, food is either typically designated as "Organic" or "Conventional" based on farming practices.
#
# Do you think we should update the "NaN" values to "Conventional"?  Why or Why not?

# %%
# Answers Question 2:
#Yes, unless there is a compelling reason to believe that the NaN values were errors or should have been Organic

# %%
# Fill the Missing Values in the Type Column
df["Type"] = df["Type"].fillna("Conventional")

# %% [markdown]
# # Question 3
#
# Based on the information provided by our team, "Grade" is only applied to canned pumpkin.
# These were all uncanned, whole pumpkins.  This column is irrelevant to the dataset.
#
# We are going to drop the column.  Do you agree with this choice?  Why or why not?

# %%
# Answer Question 3 here:
#Yes, we had already made this choice

# %%
# Grade Column 
df = df.drop(["Grade"], axis=1)

# %%
#Check with shape
df.shape
# Out:
# (166, 24)

# %% [markdown]
# # Question 4
#
# Decide which columns are relevant and irrelevant as a group.
#
# Do you think any of the columns empty for a reason?  What reason do you think?
# Is this intentional or unintentional?
# What do you think?

# %%
# Explain your rationale breifly here: 
#Sub type is likely empty for a reason because it only applies to miniature pumpkins

# %%
# Drop the ones you decide are irrelevant using the code we used to drop the "Grade Column"

df = df.drop(["Origin District"], axis=1) 
df = df.drop(["Environment"], axis=1)
df = df.drop(["Unit of Sale"], axis=1) 
df = df.drop(["Quality"], axis=1) 
df = df.drop(["Condition"], axis=1) 
df = df.drop(["Appearance"], axis=1) 
df = df.drop(["Storage"], axis=1)
df = df.drop(["Crop"], axis=1) 
df = df.drop(["Trans Mode"], axis=1)

# %%
df.shape
# Out:
# (166, 15)

# %% [markdown]
# # Question 5:
#
# Plot the outliers for them.
# histogram of date vs. sales
#
#
# What do you think about the dates?

# %%
# Answer 5 here:

#There are no valuable insights to be gleaned looking at these histograms as the dates are not in numerical order. Changing the data type to datetime will rearrange them, which allows us to see large spikes in the fall and a random spike in sales between January-February.

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.hist("Date", bins = 50, xrot=90)
# Out:
# array([[<Axes: title={'center': 'Date'}>]], dtype=object)

# %%
# # bar chart -  distribution of a categorical variable
df['Date'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# # histogram of dates.
df['Date'].hist(bins=100)
plt.xticks(rotation=90)

#ignore the lists above the histogram for right now.  Examine the histogram.
# Out:
# (array([17106., 17167., 17226., 17287., 17348., 17410.]),
#  [Text(17106.0, 0, '2016-11'),
#   Text(17167.0, 0, '2017-01'),
#   Text(17226.0, 0, '2017-03'),
#   Text(17287.0, 0, '2017-05'),
#   Text(17348.0, 0, '2017-07'),
#   Text(17410.0, 0, '2017-09')])

# %% [markdown]
# # Question 6:
#
# Are there any points in this data set that you worry about inconsistencies?
# Where?  What would you want to check?  Why?

# %%
# Answer Question 6 here: 
#The package measurements are not measured using the same units

# %% [markdown]
# # Bonus Mission
#
# Fix the LA page at this link: [A Year of Pumpkin Prices](https://www.kaggle.com/usda/a-year-of-pumpkin-prices)

# %%
df2=pd.read_csv("C:/Users/emmag/Desktop/Women+/DataCleaning-Pumpkin-Sales/los-angeles_9-24-2016_9-30-2017.csv")

# %%
df2.head(60)
# Out:
#    Commodity Name    City Name  Type        Package            Variety  \
# 0        PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 1        PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 2        PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 3        PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 4        PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 5        PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 6        PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 7        PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 8        PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 9        PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 10       PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 11       PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 12       PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 13       PUMPKINS  LOS ANGELES   NaN   24 inch bins        HOWDEN TYPE
# 14       PUMPKINS  LOS ANGELES   NaN   36 inch bins        HOWDEN TYPE
# 15       PUMPKINS  LOS ANGELES   NaN   36 inch bins        HOWDEN TYPE
# 16       PUMPKINS  LOS ANGELES   NaN   36 inch bins        HOWDEN TYPE
# 17       PUMPKINS  LOS ANGELES   NaN   36 inch bins        HOWDEN TYPE
# 18       PUMPKINS  LOS ANGELES   NaN   36 inch bins        HOWDEN TYPE
# 19       PUMPKINS  LOS ANGELES   NaN   36 inch bins        HOWDEN TYPE
# 20       PUMPKINS  LOS ANGELES   NaN           bins        HOWDEN TYPE
# 21       PUMPKINS  LOS ANGELES   NaN   36 inch bins  HOWDEN WHITE TYPE
# 22       PUMPKINS  LOS ANGELES   NaN   36 inch bins  HOWDEN WHITE TYPE
# 23       PUMPKINS  LOS ANGELES   NaN   36 inch bins  HOWDEN WHITE TYPE
# 24       PUMPKINS  LOS ANGELES   NaN   36 inch bins  HOWDEN WHITE TYPE
# 25       PUMPKINS  LOS ANGELES   NaN   36 inch bins  HOWDEN WHITE TYPE
# 26       PUMPKINS  LOS ANGELES   NaN   24 inch bins         CINDERELLA
# 27       PUMPKINS  LOS ANGELES   NaN   24 inch bins         CINDERELLA
# 28       PUMPKINS  LOS ANGELES   NaN   24 inch bins         CINDERELLA
# 29       PUMPKINS  LOS ANGELES   NaN   24 inch bins         CINDERELLA
# 30       PUMPKINS  LOS ANGELES   NaN   36 inch bins         CINDERELLA
# 31       PUMPKINS  LOS ANGELES   NaN   36 inch bins         CINDERELLA
# 32       PUMPKINS  LOS ANGELES   NaN   36 inch bins         CINDERELLA
# 33       PUMPKINS  LOS ANGELES   NaN   36 inch bins         CINDERELLA
# 34       PUMPKINS  LOS ANGELES   NaN   36 inch bins         CINDERELLA
# 35       PUMPKINS  LOS ANGELES   NaN   24 inch bins          FAIRYTALE
# 36       PUMPKINS  LOS ANGELES   NaN   24 inch bins          FAIRYTALE
# 37       PUMPKINS  LOS ANGELES   NaN   24 inch bins          FAIRYTALE
# 38       PUMPKINS  LOS ANGELES   NaN   24 inch bins          FAIRYTALE
# 39       PUMPKINS  LOS ANGELES   NaN   24 inch bins          FAIRYTALE
# 40       PUMPKINS  LOS ANGELES   NaN   24 inch bins          FAIRYTALE
# 41       PUMPKINS  LOS ANGELES   NaN   36 inch bins          FAIRYTALE
# 42       PUMPKINS  LOS ANGELES   NaN  35 lb cartons           PIE TYPE
# 43       PUMPKINS  LOS ANGELES   NaN  35 lb cartons           PIE TYPE
# 44       PUMPKINS  LOS ANGELES   NaN  35 lb cartons           PIE TYPE
# 45       PUMPKINS  LOS ANGELES   NaN   36 inch bins      BIG MACK TYPE
# 46       PUMPKINS  LOS ANGELES   NaN           each      BIG MACK TYPE
# 47       PUMPKINS  LOS ANGELES   NaN           each      BIG MACK TYPE
# 48       PUMPKINS  LOS ANGELES   NaN           each      BIG MACK TYPE
# 49       PUMPKINS  LOS ANGELES   NaN           each      BIG MACK TYPE
# 50       PUMPKINS  LOS ANGELES   NaN           each      BIG MACK TYPE
# 51       PUMPKINS  LOS ANGELES   NaN           each      BIG MACK TYPE
# 52       PUMPKINS  LOS ANGELES   NaN           each      BIG MACK TYPE
# 53       PUMPKINS  LOS ANGELES   NaN           each      BIG MACK TYPE
# 54       PUMPKINS  LOS ANGELES   NaN           each      BIG MACK TYPE
# 55       PUMPKINS  LOS ANGELES   NaN           each      BIG MACK TYPE
# 56       PUMPKINS  LOS ANGELES   NaN  35 lb cartons          MINIATURE
# 57       PUMPKINS  LOS ANGELES   NaN  35 lb cartons          MINIATURE
# 58       PUMPKINS  LOS ANGELES   NaN  35 lb cartons          MINIATURE
# 59       PUMPKINS  LOS ANGELES   NaN  35 lb cartons          MINIATURE
#
#    Sub Variety  Grade        Date  Low Price  High Price  ...   Color  \
# 0          NaN    NaN  09/24/2016     120.00      130.00  ...     NaN
# 1          NaN    NaN  09/24/2016     120.00      130.00  ...     NaN
# 2          NaN    NaN  10/01/2016     120.00      130.00  ...     NaN
# 3          NaN    NaN  10/01/2016     120.00      130.00  ...     NaN
# 4          NaN    NaN  10/08/2016     120.00      130.00  ...     NaN
# 5          NaN    NaN  10/08/2016     120.00      130.00  ...     NaN
# 6          NaN    NaN  10/15/2016     120.00      130.00  ...     NaN
# 7          NaN    NaN  10/15/2016     120.00      130.00  ...     NaN
# 8          NaN    NaN  10/22/2016     120.00      130.00  ...     NaN
# 9          NaN    NaN  10/22/2016     120.00      130.00  ...     NaN
# 10         NaN    NaN  10/29/2016      85.00      130.00  ...     NaN
# 11         NaN    NaN  10/29/2016      85.00      130.00  ...     NaN
# 12         NaN    NaN  11/05/2016      80.00       90.00  ...     NaN
# 13         NaN    NaN  11/05/2016      80.00       90.00  ...     NaN
# 14         NaN    NaN  09/16/2017     120.00      120.00  ...     NaN
# 15         NaN    NaN  09/23/2017     120.00      120.00  ...     NaN
# 16         NaN    NaN  09/30/2017     120.00      125.00  ...     NaN
# 17         NaN    NaN  09/30/2017     160.00      180.00  ...     NaN
# 18         NaN    NaN  09/30/2017     235.00      235.00  ...     NaN
# 19         NaN    NaN  09/30/2017     275.00      375.00  ...     NaN
# 20         NaN    NaN  09/24/2016     125.00      150.00  ...     NaN
# 21         NaN    NaN  09/09/2017       0.50        0.50  ...     NaN
# 22         NaN    NaN  09/16/2017       0.50        0.50  ...     NaN
# 23         NaN    NaN  09/23/2017       0.50        0.50  ...     NaN
# 24         NaN    NaN  09/30/2017     250.00      250.00  ...     NaN
# 25         NaN    NaN  09/30/2017       0.50        0.50  ...     NaN
# 26         NaN    NaN  08/19/2017       0.30        0.30  ...     NaN
# 27         NaN    NaN  08/26/2017       0.30        0.30  ...     NaN
# 28         NaN    NaN  09/02/2017       0.30        0.30  ...     NaN
# 29         NaN    NaN  09/09/2017       0.30        0.30  ...     NaN
# 30         NaN    NaN  09/09/2017       0.30        0.30  ...     NaN
# 31         NaN    NaN  09/16/2017       0.30        0.30  ...     NaN
# 32         NaN    NaN  09/23/2017       0.30        0.30  ...     NaN
# 33         NaN    NaN  09/30/2017       0.30        0.30  ...     NaN
# 34         NaN    NaN  09/30/2017     250.00      250.00  ...     NaN
# 35         NaN    NaN  09/24/2016       0.24        0.24  ...     NaN
# 36         NaN    NaN  10/01/2016       0.24        0.24  ...     NaN
# 37         NaN    NaN  10/08/2016       0.24        0.24  ...     NaN
# 38         NaN    NaN  10/15/2016       0.24        0.24  ...     NaN
# 39         NaN    NaN  10/22/2016       0.24        0.24  ...     NaN
# 40         NaN    NaN  10/29/2016       0.24        0.24  ...     NaN
# 41         NaN    NaN  09/30/2017     250.00      250.00  ...     NaN
# 42         NaN    NaN  09/16/2017      30.00       30.00  ...  ORANGE
# 43         NaN    NaN  09/23/2017      30.00       30.00  ...  ORANGE
# 44         NaN    NaN  09/30/2017      30.00       30.00  ...  ORANGE
# 45         NaN    NaN  09/30/2017       0.50        0.85  ...  ORANGE
# 46         NaN    NaN  10/01/2016     250.00      250.00  ...     NaN
# 47         NaN    NaN  10/01/2016       0.55        0.55  ...     NaN
# 48         NaN    NaN  10/08/2016     250.00      250.00  ...     NaN
# 49         NaN    NaN  10/08/2016       0.55        0.55  ...     NaN
# 50         NaN    NaN  10/15/2016     250.00      250.00  ...     NaN
# 51         NaN    NaN  10/15/2016       0.55        0.55  ...     NaN
# 52         NaN    NaN  10/22/2016     250.00      250.00  ...     NaN
# 53         NaN    NaN  10/22/2016       0.55        0.55  ...     NaN
# 54         NaN    NaN  10/29/2016     250.00      250.00  ...     NaN
# 55         NaN    NaN  10/29/2016       0.55        0.55  ...     NaN
# 56   FLAT TYPE    NaN  09/16/2017      24.50       24.50  ...  ORANGE
# 57   FLAT TYPE    NaN  09/16/2017      24.50       24.50  ...   WHITE
# 58   FLAT TYPE    NaN  09/23/2017      24.50       24.50  ...   WHITE
# 59   FLAT TYPE    NaN  09/23/2017      24.50       24.50  ...  ORANGE
#
#     Environment Unit of Sale Quality Condition Appearance  Storage Crop  \
# 0           NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 1           NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 2           NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 3           NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 4           NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 5           NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 6           NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 7           NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 8           NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 9           NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 10          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 11          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 12          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 13          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 14          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 15          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 16          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 17          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 18          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 19          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 20          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 21          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 22          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 23          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 24          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 25          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 26          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 27          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 28          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 29          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 30          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 31          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 32          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 33          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 34          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 35          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 36          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 37          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 38          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 39          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 40          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 41          NaN      PER BIN     NaN       NaN        NaN      NaN  NaN
# 42          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 43          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 44          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 45          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 46          NaN         EACH     NaN       NaN        NaN      NaN  NaN
# 47          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 48          NaN         EACH     NaN       NaN        NaN      NaN  NaN
# 49          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 50          NaN         EACH     NaN       NaN        NaN      NaN  NaN
# 51          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 52          NaN         EACH     NaN       NaN        NaN      NaN  NaN
# 53          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 54          NaN         EACH     NaN       NaN        NaN      NaN  NaN
# 55          NaN       PER LB     NaN       NaN        NaN      NaN  NaN
# 56          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 57          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 58          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 59          NaN          NaN     NaN       NaN        NaN      NaN  NaN
#
#     Repack  Trans Mode
# 0        N         NaN
# 1        N         NaN
# 2        N         NaN
# 3        N         NaN
# 4        N         NaN
# 5        N         NaN
# 6        N         NaN
# 7        N         NaN
# 8        N         NaN
# 9        N         NaN
# 10       N         NaN
# 11       N         NaN
# 12       N         NaN
# 13       N         NaN
# 14       N         NaN
# 15       N         NaN
# 16       N         NaN
# 17       N         NaN
# 18       N         NaN
# 19       N         NaN
# 20       N         NaN
# 21       N         NaN
# 22       N         NaN
# 23       N         NaN
# 24       N         NaN
# 25       N         NaN
# 26       N         NaN
# 27       N         NaN
# 28       N         NaN
# 29       N         NaN
# 30       N         NaN
# 31       N         NaN
# 32       N         NaN
# 33       N         NaN
# 34       N         NaN
# 35       N         NaN
# 36       N         NaN
# 37       N         NaN
# 38       N         NaN
# 39       N         NaN
# 40       N         NaN
# 41       N         NaN
# 42       N         NaN
# 43       N         NaN
# 44       N         NaN
# 45       N         NaN
# 46       N         NaN
# 47       N         NaN
# 48       N         NaN
# 49       N         NaN
# 50       N         NaN
# 51       N         NaN
# 52       N         NaN
# 53       N         NaN
# 54       N         NaN
# 55       N         NaN
# 56       N         NaN
# 57       N         NaN
# 58       N         NaN
# 59       N         NaN
#
# [60 rows x 25 columns]

# %%
for col in df2.columns:
    pct_missing = np.mean(df2[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 90%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 50%
# Item Size - 26%
# Color - 84%
# Environment - 100%
# Unit of Sale - 15%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
df2 = df2.drop(["Environment"], axis=1)

# %%
df2 = df2.drop(["Quality"], axis=1)

# %%
df2 = df2.drop(["Condition"], axis=1)

# %%
df2 = df2.drop(["Appearance"], axis=1)

# %%
df2 = df2.drop(["Storage"], axis=1)

# %%
df2 = df2.drop(["Crop"], axis=1)

# %%
df2["Origin District"] = df2["Origin District"].fillna("Unknown")

# %%
df2["Origin District"].head()
# Out:
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# Name: Origin District, dtype: object

# %%
df2["Item Size"] = df2["Item Size"].fillna("Unknown")

# %%
df2["Unit of Sale"] = df2["Unit of Sale"].fillna("Unknown")

# %%
df2["Color"] = df2["Color"].fillna("Unknown")

# %%
df2["Sub Variety"] = df2["Sub Variety"].fillna("N/A")

# %%
df2.head()
# Out:
#   Commodity Name    City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  LOS ANGELES   NaN  24 inch bins  HOWDEN TYPE         N/A
# 1       PUMPKINS  LOS ANGELES   NaN  24 inch bins  HOWDEN TYPE         N/A
# 2       PUMPKINS  LOS ANGELES   NaN  24 inch bins  HOWDEN TYPE         N/A
# 3       PUMPKINS  LOS ANGELES   NaN  24 inch bins  HOWDEN TYPE         N/A
# 4       PUMPKINS  LOS ANGELES   NaN  24 inch bins  HOWDEN TYPE         N/A
#
#    Grade        Date  Low Price  High Price  Mostly Low  Mostly High  \
# 0    NaN  09/24/2016      120.0       130.0       120.0        130.0
# 1    NaN  09/24/2016      120.0       130.0       120.0        130.0
# 2    NaN  10/01/2016      120.0       130.0       120.0        130.0
# 3    NaN  10/01/2016      120.0       130.0       120.0        130.0
# 4    NaN  10/08/2016      120.0       130.0       120.0        130.0
#
#        Origin Origin District Item Size    Color Unit of Sale Repack  \
# 0  CALIFORNIA         Unknown       lge  Unknown      PER BIN      N
# 1  CALIFORNIA         Unknown       med  Unknown      PER BIN      N
# 2  CALIFORNIA         Unknown       lge  Unknown      PER BIN      N
# 3  CALIFORNIA         Unknown       med  Unknown      PER BIN      N
# 4  CALIFORNIA         Unknown       lge  Unknown      PER BIN      N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
